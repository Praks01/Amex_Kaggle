# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
# %matplotlib inline

# %%
df_train = pd.read_csv(r"C:\Users\praka\Desktop\Studies\AmEXkaggle\amex-default-prediction\train_data.csv")

# %%
df_head = df_train.head()

# %%
df_head.to_csv('train_head.csv')

# %%
df_train.tail()
# Out:
#                                                customer_ID         S_2  \
# 5531446  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2017-11-05
# 5531447  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2017-12-23
# 5531448  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-01-06
# 5531449  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-02-06
# 5531450  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-03-14
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 5531446  0.979332  0.416013  0.020818  0.828199  0.003487  0.090743  0.005340
# 5531447  0.984907  0.296536  0.007209  0.812610  0.005904  0.079886  0.002243
# 5531448  0.983019  0.443984  0.013151  0.815422  0.003457  0.100503  0.002111
# 5531449  0.969861  0.442553  0.009855  1.003541  0.005117  0.101802  0.009930
# 5531450  0.982175  0.002474  0.000077  0.992880  0.000809  0.119165  0.003287
#
# ...

# %%
df_train.shape
# Out:
# (5531451, 190)

# %%
for col in df_train.columns:
    print(f"{col} \t {df_train[col].dtype}")
# Out:
# customer_ID 	 object
# S_2 	 object
# P_2 	 float64
# D_39 	 float64
# B_1 	 float64
# B_2 	 float64
# R_1 	 float64
# S_3 	 float64
# D_41 	 float64
# B_3 	 float64
# D_42 	 float64
# D_43 	 float64
# D_44 	 float64
# B_4 	 float64
# D_45 	 float64
# B_5 	 float64
# R_2 	 float64
# D_46 	 float64
# D_47 	 float64
# D_48 	 float64
# D_49 	 float64
# B_6 	 float64
# B_7 	 float64
# B_8 	 float64
# D_50 	 float64
# D_51 	 float64
# B_9 	 float64
# R_3 	 float64
# D_52 	 float64
# P_3 	 float64
# B_10 	 float64
# D_53 	 float64
# S_5 	 float64
# B_11 	 float64
# S_6 	 float64
# D_54 	 float64
# R_4 	 float64
# S_7 	 float64
# B_12 	 float64
# S_8 	 float64
# D_55 	 float64
# D_56 	 float64
# B_13 	 float64
# R_5 	 float64
# D_58 	 float64
# S_9 	 float64
# B_14 	 float64
# D_59 	 float64
# D_60 	 float64
# D_61 	 float64
# B_15 	 float64
# S_11 	 float64
# D_62 	 float64
# D_63 	 object
# D_64 	 object
# D_65 	 float64
# B_16 	 float64
# B_17 	 float64
# B_18 	 float64
# B_19 	 float64
# ...

# %%
df_train['D_63']
# Out:
# 0          CR
# 1          CR
# 2          CR
# 3          CR
# 4          CR
#            ..
# 5531446    CL
# 5531447    CL
# 5531448    CL
# 5531449    CL
# 5531450    CL
# Name: D_63, Length: 5531451, dtype: object

# %%
df_train['D_63'].value_counts()
# Out:
# CO    4119621
# CR     930133
# CL     438390
# XZ      25786
# XM      10556
# XL       6965
# Name: D_63, dtype: int64

# %%
df_train['D_64']
# Out:
# 0          O
# 1          O
# 2          O
# 3          O
# 4          O
#           ..
# 5531446    O
# 5531447    O
# 5531448    O
# 5531449    O
# 5531450    O
# Name: D_64, Length: 5531451, dtype: object

# %%
df_train['D_64'].value_counts()
# Out:
# O     2913244
# U     1523448
# R      840112
# -1      37205
# Name: D_64, dtype: int64

# %%
df_train['D_63'] = df_train['D_63'].astype('category')
df_train['D_64'] = df_train['D_64'].astype('category')

# %%
df_train['D_63_new'] = df_train['D_63'].cat.codes
df_train['D_64_new'] = df_train['D_64'].cat.codes

# %%
enc=OneHotEncoder()
enc_data=pd.DataFrame(enc.fit_transform(df_train[['D_63_new','D_64_new']]).toarray())

# %%
df_train = df_train.join(enc_data)

# %%
df_train['S_2'] = pd.to_datetime(df_train['S_2'])

# %%
df_train.dtypes
# Out:
# customer_ID            object
# S_2            datetime64[ns]
# P_2                   float64
# D_39                  float64
# B_1                   float64
#                     ...
# 6                     float64
# 7                     float64
# 8                     float64
# 9                     float64
# 10                    float64
# Length: 203, dtype: object

# %%
df_train.count()
# Out:
# customer_ID    5531451
# S_2            5531451
# P_2            5485466
# D_39           5531451
# B_1            5531451
#                 ...
# 6              5531451
# 7              5531451
# 8              5531451
# 9              5531451
# 10             5531451
# Length: 203, dtype: int64

# %%
df_train.describe(include='all')
# Out:
# <ipython-input-19-b75fe9c527f9>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_train.describe(include='all')
#                                               customer_ID  \
# count                                             5531451
# unique                                             458913
# top     08c57c902d75c37c27c892b986b16942337d2a0659a0e2...
# freq                                                   13
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# ...

# %%
df_na=pd.DataFrame(df_train.isna().sum())

# %%
df_na.head()
# Out:
#                  0
# customer_ID      0
# S_2              0
# P_2          45985
# D_39             0
# B_1              0

# %%
for item in df_na['0']:
    print(item)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-07d9c53baa80> in <module>
# ----> 1 for item in df_na['0']:
#       2     print(item)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# KeyError: '0'

# %%
display(df_na.to_string)
# Out:
# <bound method DataFrame.to_string of                  0
# customer_ID      0
# S_2              0
# P_2          45985
# D_39             0
# B_1              0
# ...            ...
# 6                0
# 7                0
# 8                0
# 9                0
# 10               0
#
# [203 rows x 1 columns]>

# %%
df_customer = df_train.groupby('customer_ID')

# %%
df_customer.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-24-c84971fd1e3e> in <module>
# ----> 1 df_customer.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in head(self, n)
#    2796         mask = self._cumcount_array() < n
#    2797         if self.axis == 0:
# -> 2798             return self._selected_obj[mask]
#    2799         else:
#    2800             return self._selected_obj.iloc[:, mask]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
# ...

# %%
transaction_count = df_customer['S_2'].count()

# %%
transaction_count.head()

# %%
transaction_count.shape

# %%
transaction_count.describe()

# %% [markdown]
# OBSERVATIONS:
#     Unique Customers - 458913
#     No. of transaction data/customer - 1 to 13

# %%
df_train.isna().sum()/df_train.shape[0]

# %%
# Reading the train labels
train_labels = pd.read_csv(r"C:\Users\praka\Desktop\Studies\AmEXkaggle\amex-default-prediction\train_labels.csv")

# %%
train_labels.describe()

# %%
train_labels.head()
