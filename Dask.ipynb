# %%
from dask.distributed import Client

client = Client(n_workers=4)
client
# Out:
# <Client: 'tcp://127.0.0.1:62834' processes=4 threads=8, memory=7.92 GiB>

# %%
import dask
import dask.dataframe as dd
from dask.delayed import delayed
import pandas as pd

# %%
df_raw_train = dd.read_csv("train_data.csv")

# %%
df_raw_train
# Out:
# Dask DataFrame Structure:
# ...

# %%
df_train_label = dd.read_csv("train_labels.csv")
df_train_label
# Out:
# Dask DataFrame Structure:
#               customer_ID target
# npartitions=1
#                    object  int64
#                       ...    ...
# Dask Name: read-csv, 1 tasks

# %%
combine = dd.merge(df_raw_train, df_train_label, on='customer_ID', how='outer')
df_train_combined = combine.compute()
# Out:
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# ...
